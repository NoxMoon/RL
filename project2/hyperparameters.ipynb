# %%
import json
import matplotlib.pyplot as plt

# %%
for lr in [0.005, 0.001, 0.0005, 0.0001]:
    results = json.load(open(f'experiments/lr{lr}_e0.995_tau0.001_gamma1.txt'))
    #print(f'experiments/lr{lr}_e0.995_tau0.001_gamma0.99.txt')
    print(results['params'])
    #plt.plot(results['rewards'])
    plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label=f"lr={lr}")

plt.xlabel("episode")
plt.ylabel("reward")
plt.legend()
plt.savefig("figures/lr_gamma1.png")
plt.show()
# Out:
# {'batch_size': 32, 'gamma': 1, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.005}
# {'batch_size': 32, 'gamma': 1, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.001}
# {'batch_size': 32, 'gamma': 1, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 1, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0001}

# %%
#result = json.load(open(f'experiments/default.txt'))
#plt.plot(range(100, len(results['rewards'])), results['moving_avg'], label=f"lr={0.0005}")

for lr in [0.005, 0.001, 0.0005, 0.0001]:    
    results = json.load(open(f'experiments/lr{lr}_e0.995_tau0.001_gamma0.99.txt'))
    #print(f'experiments/lr{lr}_e0.995_tau0.001_gamma0.99.txt')
    print(results['params'])
    
    #plt.plot(results['rewards'])
    plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label=f"lr={lr}")

plt.xlabel("episode")
plt.ylabel("reward")
plt.legend()
plt.savefig("figures/lr.png")
plt.show()
# Out:
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.005}
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.001}
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0001}

# %%
for tau in [0.005, 0.002, 0.001, 0.0005, 0.0002, 0.0001]:
    results = json.load(open(f'experiments/lr0.0005_e0.995_tau{tau}_gamma1.txt'))
    print(f'experiments/lr{lr}_e0.995_tau0.001_gamma0.99.txt')
    print(results['params'])
    plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label=f"tau={tau}")

plt.xlabel("episode")
plt.ylabel("reward")
plt.legend()
plt.ylim(-500)
plt.savefig("figures/tau_gamma1.png")
plt.show()
# Out:
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 1, 'tau': 0.005, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 1, 'tau': 0.002, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 1, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 1, 'tau': 0.0005, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 1, 'tau': 0.0002, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 1, 'tau': 0.0001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}

# %%
for tau in [0.005, 0.002, 0.001, 0.0005, 0.0002, 0.0001]:
    results = json.load(open(f'experiments/lr0.0005_e0.995_tau{tau}_gamma0.99.txt'))
    print(f'experiments/lr{lr}_e0.995_tau0.001_gamma0.99.txt')
    print(results['params'])
    plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label=f"tau={tau}")

plt.xlabel("episode")
plt.ylabel("reward")
plt.legend()
plt.savefig("figures/tau.png")
plt.show()
# Out:
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.005, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.002, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.0005, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.0002, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# experiments/lr0.0001_e0.995_tau0.001_gamma0.99.txt
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.0001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}

# %%
for epsilon_decay in [0.999, 0.995, 0.99, 0.95]:
    results = json.load(open(f'experiments/lr0.0005_e{epsilon_decay}_tau0.001_gamma0.99.txt'))
    print(results['params'])
    #plt.plot(results['rewards'])
    plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label=f"epsilon_decay={epsilon_decay}")

plt.xlabel("episode")
plt.ylabel("reward")
plt.legend()
plt.savefig("figures/epsilon_decay.png")
plt.show()
# Out:
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.999, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.99, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.95, 'lr': 0.0005}

# %%
results = json.load(open(f'experiments/lr0.0005_e0.995_tau0.001_gamma0.99.txt'))
print(results['params'])
plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label='run1')
results = json.load(open(f'experiments/lr0.0005_e0.995_tau0.001_gamma0.99_2.txt'))
print(results['params'])
plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label='run2')
results = json.load(open(f'experiments/lr0.0005_e0.995_tau0.001_gamma0.99_3.txt'))
print(results['params'])
plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label='run3')
results = json.load(open(f'experiments/final_model3.txt'))
print(results['params'])
plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label='run3')
plt.xlabel("episode")
plt.ylabel("reward")
plt.legend()
plt.savefig("figures/gamma099.png")
plt.show()
# Out:
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 0.99, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}

# %%
results = json.load(open(f'experiments/lr0.0005_e0.995_tau0.001_gamma1_1.txt'))
print(results['params'])
plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label='run1')
results = json.load(open(f'experiments/lr0.0005_e0.995_tau0.001_gamma1_2.txt'))
print(results['params'])
plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label='run2')
results = json.load(open(f'experiments/lr0.0005_e0.995_tau0.001_gamma1_3.txt'))
print(results['params'])
plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label='run3')
results = json.load(open(f'experiments/lr0.0005_e0.995_tau0.001_gamma1.txt'))
print(results['params'])
plt.plot(range(100-1, len(results['episode_rewards'])), results['moving_avg'], label='run4')
plt.xlabel("episode")
plt.ylabel("reward")
plt.legend()
plt.savefig("figures/gamma1.png")
plt.show()
# Out:
# {'batch_size': 32, 'gamma': 1, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 1, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 1, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
# {'batch_size': 32, 'gamma': 1, 'tau': 0.001, 'epsilon': 1, 'epsilon_decay': 0.995, 'lr': 0.0005}
